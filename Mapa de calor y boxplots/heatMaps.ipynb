# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
dia = pd.read_csv('Diamonds are forever.csv', na_values = '')
dia
# Out:
#      Carat  Colour  Clarity  Lab  Price ($US)
# 0     0.30       1        5    1        911.4
# 1     0.30       2        4    1       1057.0
# 2     0.30       4        2    1       1057.0
# 3     0.30       4        4    1        882.0
# 4     0.31       1        4    1       1148.7
# ..     ...     ...      ...  ...          ...
# 303   1.01       6        4    3       5722.5
# 304   1.02       3        3    3       7557.2
# 305   1.06       5        3    3       6923.0
# 306   1.02       5        5    3       6271.3
# 307   1.09       6        3    3       6374.9
#
# [308 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.distplot(dia['Carat'], bins=30)
plt.show()
# Out:
# /home/the_nutscout/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.distplot(dia['Colour'], bins=6)
plt.show()
# Out:
# /home/the_nutscout/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.distplot(dia['Clarity'], bins=5)
plt.show()
# Out:
# /home/the_nutscout/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.distplot(dia['Lab'], bins=3)
plt.show()
# Out:
# /home/the_nutscout/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(11.7, 8.27)})
sns.distplot(dia['Price ($US)'], bins=50)
plt.show()
# Out:
# /home/the_nutscout/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
correlation_matrix = dia.corr().round(2)

sns.heatmap(data = correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(dia['Price ($US)'], notch=True)
plt.show()
